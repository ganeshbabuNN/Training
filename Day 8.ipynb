# %%
import pandas as pd

# %%
nba=pd.read_csv("nba.csv")
type(nba)
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#attributes
nba.ndim
nba.index
nba.values
nba.columns
nba.axes
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
#methods
nba.head()
nba.head(30)
nba.tail()
nba.tail(20)
nba.dtypes.value_counts()
# Out:
# object     5
# float64    4
# dtype: int64

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba['Name']
nba.Name
nba['Age']
nba['College']
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# 457                  NaN
# Name: College, Length: 458, dtype: object

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba[['Name','Salary']]
nba[['Name','Age']]
nba[['Name','Team','Age','Salary']]
# Out:
#               Name            Team   Age     Salary
# 0    Avery Bradley  Boston Celtics  25.0  7730337.0
# 1      Jae Crowder  Boston Celtics  25.0  6796117.0
# 2     John Holland  Boston Celtics  27.0        NaN
# 3      R.J. Hunter  Boston Celtics  22.0  1148640.0
# 4    Jonas Jerebko  Boston Celtics  29.0  5000000.0
# ..             ...             ...   ...        ...
# 453   Shelvin Mack       Utah Jazz  26.0  2433333.0
# 454      Raul Neto       Utah Jazz  24.0   900000.0
# 455   Tibor Pleiss       Utah Jazz  26.0  2900000.0
# 456    Jeff Withey       Utah Jazz  26.0   947276.0
# 457            NaN             NaN   NaN        NaN
#
# [458 rows x 4 columns]

# %%
mycols=['Name','Position','Age']

# %%
mycols
# Out:
# ['Name', 'Position', 'Age']

# %%
nba[mycols]
# Out:
#               Name Position   Age
# 0    Avery Bradley       PG  25.0
# 1      Jae Crowder       SF  25.0
# 2     John Holland       SG  27.0
# 3      R.J. Hunter       SG  22.0
# 4    Jonas Jerebko       PF  29.0
# ..             ...      ...   ...
# 453   Shelvin Mack       PG  26.0
# 454      Raul Neto       PG  24.0
# 455   Tibor Pleiss        C  26.0
# 456    Jeff Withey        C  26.0
# 457            NaN      NaN   NaN
#
# [458 rows x 3 columns]

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba['Sports']='Basket Ball'

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary       Sports
# ...

# %%
nba['Leage']="National Basket Ball Tournament"

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary       Sports  \
# ...

# %%
nba=pd.read_csv("nba.csv")

# %%
nba.insert(5,column="Sports",value="Basket Ball")

# %%
nba.insert(8,column="League",value="National Basket Ball Tournament")

# %%
nba
# Out:
#               Name            Team  Number Position   Age       Sports Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0  Basket Ball    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0  Basket Ball    6-6
# 2     John Holland  Boston Celtics    30.0       SG  27.0  Basket Ball    6-5
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0  Basket Ball    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0  Basket Ball   6-10
# ..             ...             ...     ...      ...   ...          ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0  Basket Ball    6-3
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0  Basket Ball    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0  Basket Ball    7-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0  Basket Ball    7-0
# 457            NaN             NaN     NaN      NaN   NaN  Basket Ball    NaN
#
# ...

# %%
nba['currentSal']=nba['Salary']-5000
nba['currentSal']=nba['Salary'].sub(5000)

# %%
nba
# Out:
#               Name            Team  Number Position   Age       Sports Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0  Basket Ball    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0  Basket Ball    6-6
# 2     John Holland  Boston Celtics    30.0       SG  27.0  Basket Ball    6-5
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0  Basket Ball    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0  Basket Ball   6-10
# ..             ...             ...     ...      ...   ...          ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0  Basket Ball    6-3
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0  Basket Ball    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0  Basket Ball    7-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0  Basket Ball    7-0
# 457            NaN             NaN     NaN      NaN   NaN  Basket Ball    NaN
#
# ...

# %%
nba['currentSal mul']=nba['Salary']*.05
nba['currentSal mul']=nba['Salary'].mul(.05)

# %%
nba['currentSal div']=nba['Salary']/10000
nba['currentSal div']=nba['Salary'].div(10000)

# %%
nba.dtypes
len(nba.dtypes)
nba.dtypes.count()
# Out:
# 14

# %%
nba=pd.read_csv("nba.csv")

# %%
nba['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# San Antonio Spurs         15
# Sacramento Kings          15
# Golden State Warriors     15
# Dallas Mavericks          15
# Indiana Pacers            15
# Houston Rockets           15
# Boston Celtics            15
# Detroit Pistons           15
# Portland Trail Blazers    15
# Washington Wizards        15
# Los Angeles Lakers        15
# Toronto Raptors           15
# Brooklyn Nets             15
# Phoenix Suns              15
# Denver Nuggets            15
# Atlanta Hawks             15
# Charlotte Hornets         15
# Chicago Bulls             15
# Los Angeles Clippers      15
# Philadelphia 76ers        15
# Miami Heat                15
# Utah Jazz                 15
# Cleveland Cavaliers       15
# Oklahoma City Thunder     15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
col =['College','Team']
nba[col].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-89ba09ba69bd> in <module>
#       1 col =['College','Team']
# ----> 2 nba[col].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
nba['Team'].value_counts().sort_values(ascending=False).tail(10)
# Out:
# Charlotte Hornets         15
# Chicago Bulls             15
# Los Angeles Clippers      15
# Philadelphia 76ers        15
# Miami Heat                15
# Utah Jazz                 15
# Cleveland Cavaliers       15
# Oklahoma City Thunder     15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
#dropna methods remove that the paritcular row which contain any or all null values
nba.dropna(how='all',inplace=True)

# %%
nba.dropna(subset=['College',"Salary"]).tail()
# Out:
#               Name       Team  Number Position   Age Height  Weight   College  \
# 449    Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0      Duke
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0    Dayton
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 449  1348440.0
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 456   947276.0

# %%
nba.dropna(axis='columns',how='any')
# Out:
#               Name            Team  Number Position   Age Height  Weight
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
# [457 rows x 7 columns]
