# %%
import pandas as pd

# %%
pokemon=pd.read_csv("pokemon.csv",usecols=['Pokemon'],squeeze=True)
google=pd.read_csv("google_stock_price.csv",usecols=['Stock Price'],squeeze=True)

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
len(pokemon)
len(google)
# Out:
# 3012

# %%
type(pokemon)
type(google)
# Out:
# pandas.core.series.Series

# %%
type(len(dir(pokemon)))
# Out:
# int

# %%
type(sorted(pokemon))
type(sorted(google))
# Out:
# list

# %%
sorted(pokemon,reverse=True)
# Out:
# ['Zygarde',
#  'Zweilous',
#  'Zubat',
#  'Zorua',
#  'Zoroark',
#  'Zigzagoon',
#  'Zekrom',
#  'Zebstrika',
#  'Zapdos',
#  'Zangoose',
#  'Yveltal',
#  'Yanmega',
#  'Yanma',
#  'Yamask',
#  'Xerneas',
#  'Xatu',
#  'Wynaut',
#  'Wurmple',
#  'Wormadam',
#  'Wooper',
#  'Woobat',
#  'Wobbuffet',
#  'Wingull',
#  'Wigglytuff',
#  'Whismur',
#  'Whiscash',
#  'Whirlipede',
#  'Whimsicott',
#  'Weezing',
#  'Weepinbell',
#  'Weedle',
#  'Weavile',
#  'Watchog',
#  'Wartortle',
#  'Walrein',
#  'Wailord',
#  'Wailmer',
#  'Vulpix',
#  'Vullaby',
#  'Voltorb',
#  'Volcarona',
#  'Volcanion',
#  'Volbeat',
#  'Vivillon',
#  'Virizion',
#  'Vileplume',
#  'Vigoroth',
#  'Victreebel',
#  'Victini',
#  'Vibrava',
#  'Vespiquen',
#  'Venusaur',
#  'Venonat',
#  'Venomoth',
#  'Venipede',
#  'Vaporeon',
#  'Vanilluxe',
#  'Vanillite',
#  'Vanillish',
#  'Uxie',
#  'Ursaring',
#  'Unown',
#  'Unfezant',
#  'Umbreon',
#  'Tyrunt',
#  'Tyrogue',
#  'Tyrantrum',
#  'Tyranitar',
#  'Typhlosion',
# ...

# %%
list(pokemon)
pd.Series(list(set(google))).to_csv("kfu.csv")

# %%
dict(google)
dict(pokemon)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
max(google)
min(google)
# Out:
# 49.95

# %%
max(pokemon)
# Out:
# 'Zygarde'

# %%
pokemon.tail()
# Out:
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %%
mylist=["AA","AZ","BB","BA"]

# %%
max(mylist)
# Out:
# 'BB'

# %%
pokemon=pd.read_csv("pokemon.csv",usecols=['Pokemon'],squeeze=True)
google=pd.read_csv("google_stock_price.csv",usecols=['Stock Price'],squeeze=True)

# %%
pokemon=pd.read_csv("pokemon.csv")
google=pd.read_csv("google_stock_price.csv")

# %%
type(pokemon.values)
google.values
# Out:
# array([ 50.12,  54.1 ,  54.65, ..., 773.18, 771.61, 782.22])

# %%
pokemon.index
google.index
# Out:
# RangeIndex(start=0, stop=3012, step=1)

# %%
pokemon.dtypes
google.dtypes
# Out:
# dtype('float64')

# %%
pokemon.is_unique
# Out:
# True

# %%
google.is_unique
# Out:
# False

# %%
pokemon.ndim
google.ndim
# Out:
# 2

# %%
pokemon.shape
google.shape
# Out:
# (3012, 1)

# %%
len(pokemon)
pokemon.size
# Out:
# 721

# %%
pokemon.name='Pocket monster'

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pocket monster, Length: 721, dtype: object
