# %%
import pandas as pd

# %%
nba=pd.read_csv("nba.csv")

# %%
nba.sort_values("College")
nba.sort_values("College",ascending=True,inplace=True)
nba.sort_index()
# Out:
#      index            Name                  Team  Number Position   Age  \
# 0      287      Alonzo Gee  New Orleans Pelicans    15.0       SF  29.0
# 1      266  JaMychal Green     Memphis Grizzlies     0.0       PF  25.0
# 2      180     Mo Williams   Cleveland Cavaliers    52.0       PG  33.0
# 3      201     Jordan Hill        Indiana Pacers    27.0        C  28.0
# 4      202    Solomon Hill        Indiana Pacers    44.0       SF  25.0
# ..     ...             ...                   ...     ...      ...   ...
# 453    447     Rudy Gobert             Utah Jazz    27.0        C  23.0
# 454    450      Joe Ingles             Utah Jazz     2.0       SF  28.0
# 455    454       Raul Neto             Utah Jazz    25.0       PG  24.0
# 456    455    Tibor Pleiss             Utah Jazz    21.0        C  26.0
# 457    457             NaN                   NaN     NaN      NaN   NaN
#
#     Height  Weight  College     Salary
# 0      6-6   225.0  Alabama  1320000.0
# ...

# %%
nba
# Out:
#      level_0  index            Name                  Team  Number Position  \
# 0          0    287      Alonzo Gee  New Orleans Pelicans    15.0       SF
# 1          1    266  JaMychal Green     Memphis Grizzlies     0.0       PF
# 2          2    180     Mo Williams   Cleveland Cavaliers    52.0       PG
# 3          9    356    Aaron Gordon         Orlando Magic     0.0       PF
# 4         15    123  Chase Budinger          Phoenix Suns    10.0       SF
# ..       ...    ...             ...                   ...     ...      ...
# 453      453    447     Rudy Gobert             Utah Jazz    27.0        C
# 454      454    450      Joe Ingles             Utah Jazz     2.0       SF
# 455      455    454       Raul Neto             Utah Jazz    25.0       PG
# 456      456    455    Tibor Pleiss             Utah Jazz    21.0        C
# 457      457    457             NaN                   NaN     NaN      NaN
#
#       Age Height  Weight  College     Salary
# ...

# %%
nba
# Out:
#      level_0  index            Name                  Team  Number Position  \
# 0          0    287      Alonzo Gee  New Orleans Pelicans    15.0       SF
# 1          1    266  JaMychal Green     Memphis Grizzlies     0.0       PF
# 2          2    180     Mo Williams   Cleveland Cavaliers    52.0       PG
# 3          9    356    Aaron Gordon         Orlando Magic     0.0       PF
# 4         15    123  Chase Budinger          Phoenix Suns    10.0       SF
# ..       ...    ...             ...                   ...     ...      ...
# 453      453    447     Rudy Gobert             Utah Jazz    27.0        C
# 454      454    450      Joe Ingles             Utah Jazz     2.0       SF
# 455      455    454       Raul Neto             Utah Jazz    25.0       PG
# 456      456    455    Tibor Pleiss             Utah Jazz    21.0        C
# 457      457    457             NaN                   NaN     NaN      NaN
#
#       Age Height  Weight  College     Salary
# ...

# %%
nba.sort_values("Salary",ascending=False)
# Out:
#      level_0  index             Name                 Team  Number Position  \
# 391      391    109      Kobe Bryant   Los Angeles Lakers    24.0       SF
# 401      401    169     LeBron James  Cleveland Cavaliers    23.0       SF
# 279      278     33  Carmelo Anthony      New York Knicks     7.0       SF
# 413      413    251    Dwight Howard      Houston Rockets    12.0        C
# 105      105    339       Chris Bosh           Miami Heat     1.0       PF
# ..       ...    ...              ...                  ...     ...      ...
# 326      322    273   Alex Stepheson    Memphis Grizzlies    35.0       PF
# 341      341    350    Briante Weber           Miami Heat    12.0       PG
# 433      433    353    Dorell Wright           Miami Heat    11.0       SF
# 445      445    397     Axel Toupane       Denver Nuggets     6.0       SG
# 457      457    457              NaN                  NaN     NaN      NaN
#
#       Age Height  Weight                College      Salary
# ...

# %%
nba['Salary Rank']=nba['Salary'].rank(ascending=False)

# %%
nba.sort_values("Salary Rank",ascending=True)
# Out:
#      level_0  index             Name                 Team  Number Position  \
# 391      391    109      Kobe Bryant   Los Angeles Lakers    24.0       SF
# 401      401    169     LeBron James  Cleveland Cavaliers    23.0       SF
# 279      278     33  Carmelo Anthony      New York Knicks     7.0       SF
# 413      413    251    Dwight Howard      Houston Rockets    12.0        C
# 105      105    339       Chris Bosh           Miami Heat     1.0       PF
# ..       ...    ...              ...                  ...     ...      ...
# 326      322    273   Alex Stepheson    Memphis Grizzlies    35.0       PF
# 341      341    350    Briante Weber           Miami Heat    12.0       PG
# 433      433    353    Dorell Wright           Miami Heat    11.0       SF
# 445      445    397     Axel Toupane       Denver Nuggets     6.0       SG
# 457      457    457              NaN                  NaN     NaN      NaN
#
# ...

# %%
nba.tail(50)
# Out:
#      level_0  index                Name                    Team  Number  \
# 408      408    217       Damien Inglis         Milwaukee Bucks    17.0
# 409      409    235         Salah Mejri        Dallas Mavericks    50.0
# 410      410    236       Dirk Nowitzki        Dallas Mavericks    41.0
# 411      411    237       Zaza Pachulia        Dallas Mavericks    27.0
# 412      412    246        Clint Capela         Houston Rockets    15.0
# 413      413    251       Dwight Howard         Houston Rockets    12.0
# 414      414    254  Donatas Motiejunas         Houston Rockets    20.0
# 415      415    255          Josh Smith         Houston Rockets     5.0
# 416      416    265          Marc Gasol       Memphis Grizzlies    33.0
# 417      417    275       Alexis Ajinca    New Orleans Pelicans    42.0
# 418      418    277           Omer Asik    New Orleans Pelicans     3.0
# 419      419    292    Kendrick Perkins    New Orleans Pelicans     5.0
# ...

# %%
nba.sort_values("Salary",na_position="last").tail(50)
# Out:
#      level_0  index               Name                    Team  Number  \
# 440      440    388   Danilo Gallinari          Denver Nuggets     8.0
# 289      289    179   Tristan Thompson     Cleveland Cavaliers    13.0
# 198      199     82     Draymond Green   Golden State Warriors    23.0
# 300      300    219    Khris Middleton         Milwaukee Bucks    22.0
# 430      430    341       Goran Dragic              Miami Heat     7.0
# 84        87    238   Chandler Parsons        Dallas Mavericks    25.0
# 30        30    448     Gordon Hayward               Utah Jazz    20.0
# 358      357     89      Klay Thompson   Golden State Warriors    11.0
# 116      116    288        Eric Gordon    New Orleans Pelicans    10.0
# 100      100    111        Roy Hibbert      Los Angeles Lakers    17.0
# 17        17    249       James Harden         Houston Rockets    13.0
# 151      162    382          John Wall      Washington Wizards     2.0
# ...

# %%
emp=pd.read_csv("employees.csv")

# %%
emp.info(memory_usage=True)
emp.memory_usage()
emp.memory_usage(deep=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB
# Index                  128
# First Name           60716
# Gender               57657
# Start Date           65963
# Last Login Time      64239
# Salary                8000
# Bonus %               8000
# Senior Management    33872
# Team                 66163
# dtype: int64

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
emp["Gender"]=emp["Gender"].astype("category")
emp['Start Date']=pd.to_datetime(emp['Start Date'])
emp['Last Login Time']=pd.to_datetime(emp['Last Login Time'])
emp["Senior Management"]=emp["Senior Management"].astype("bool")
emp["Team"]=emp["Team"].astype("category")

# %%
pd.read_csv("sto")
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
cond1 = emp['Gender']=='Male'

# %%
emp[cond1]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-02-03 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2021-02-03 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2021-02-03 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-02-03 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-02-03 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2021-02-03 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2021-02-03 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-02-03 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-02-03 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-02-03 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[emp['Gender']=='Male']
# Out:
#       First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 39           NaN   Male 2016-01-29 2021-02-03 02:33:00  122173    7.797
# 195       Ronald   Male 2014-04-30 2021-02-03 14:19:00  121068   12.757
# 225        Harry   Male 2015-10-01 2021-02-03 19:47:00   64579   15.266
# 301        James   Male 2015-07-11 2021-02-03 20:52:00   72257   13.023
# 330        Randy   Male 2014-03-16 2021-02-03 18:24:00  135119    7.887
# 335       Robert   Male 2014-11-18 2021-02-03 05:00:00   85799   19.930
# 357      Russell   Male 2014-08-13 2021-02-03 15:51:00  121160    7.843
# 376      Brandon   Male 2015-10-16 2021-02-03 02:44:00  112548    4.664
# 426         Todd   Male 2016-03-16 2021-02-03 14:45:00  134408    3.560
# 444          NaN   Male 2016-05-24 2021-02-03 21:17:00   76409    7.008
# 469      Stephen   Male 2015-05-09 2021-02-03 19:07:00  141958    9.078
# 496       Johnny   Male 2016-02-26 2021-02-03 19:39:00   76394    5.437
# ...

# %%
cond1=emp['Senior Management']==False
cond2 = emp['Gender']=='Male'

# %%
emp[cond1 & cond2]
# Out:
#      First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 43      Marilyn  Female 1980-12-07 2021-02-03 03:16:00   73524    5.207
# 62          NaN  Female 2007-06-12 2021-02-03 17:25:00   58112   19.414
# 98         Tina  Female 2016-06-16 2021-02-03 19:47:00  100705   16.961
# 140     Shirley  Female 1981-02-28 2021-02-03 13:23:00  113850    1.854
# 158       Norma  Female 1999-02-28 2021-02-03 20:45:00  114412    8.756
# 201    Kimberly  Female 1997-07-15 2021-02-03 05:57:00   36643    7.953
# 220         NaN  Female 1991-06-17 2021-02-03 12:49:00   71945    5.560
# 305    Margaret  Female 1993-02-06 2021-02-03 13:05:00  125220    3.733
# 319  Jacqueline  Female 1981-11-25 2021-02-03 15:01:00  145988   18.243
# 331      Evelyn  Female 1983-09-03 2021-02-03 13:58:00   36759   17.269
# 379         NaN  Female 2002-09-18 2021-02-03 12:39:00  118906    4.537
# 446      Cheryl  Female 1994-08-16 2021-02-03 08:33:00   67150   15.850
# ...

# %%
cond1=
cond2 =

# %%
emp[(emp['Gender']=='Female') | (emp['Team']=='Marketing')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-02-03 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2021-02-03 11:17:00  130590   11.858
# 6         Ruby  Female 1987-08-17 2021-02-03 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2021-02-03 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2021-02-03 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 988      Alice  Female 2004-10-05 2021-02-03 09:34:00   47638   11.209
# 990      Robin  Female 1987-07-24 2021-02-03 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2021-02-03 05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15 2021-02-03 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2021-02-03 17:47:00   98874    4.479
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp['Start Date'].min()
# Out:
# Timestamp('1980-01-19 00:00:00')

# %%
cond=emp['Start Date'] > "2014-01-01"
emp[~cond]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
emp.sort_values("Start Date",ascending=True).count()
# Out:
# First Name           57
# Gender               50
# Start Date           64
# Last Login Time      64
# Salary               64
# Bonus %              64
# Senior Management    64
# Team                 62
# dtype: int64

# %%
emp['Team'].unique().to_list()
# Out:
# ['Finance',
#  'Product',
#  'Client Services',
#  'Business Development',
#  'Legal',
#  'Marketing',
#  'Engineering',
#  'Distribution',
#  'Sales',
#  'Human Resources',
#  nan]

# %%
emp['Team']=='Marketing'
emp['Team']=='Engineering'
emp['Team']=='Sales'
# Out:
# 7      False
# 15     False
# 39     False
# 41     False
# 53     False
#        ...
# 942    False
# 955    False
# 967    False
# 987    False
# 995    False
# Name: Team, Length: 64, dtype: bool

# %%
cond=emp['Team'].isin(["Marketing",'Engineering','Sales'])

# %%
emp[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 7          NaN  Female 2015-07-20 2021-02-03 10:43:00   45906   11.598
# 15     Lillian  Female 2016-06-05 2021-02-03 06:09:00   59414    1.256
# 39         NaN    Male 2016-01-29 2021-02-03 02:33:00  122173    7.797
# 41   Christine     NaN 2015-06-28 2021-02-03 01:08:00   66582   11.308
# 53        Alan     NaN 2014-03-03 2021-02-03 13:28:00   40341   17.578
# ..         ...     ...        ...                 ...     ...      ...
# 942       Lori  Female 2015-11-20 2021-02-03 13:15:00   75498    6.537
# 955      Sarah  Female 2014-08-17 2021-02-03 23:08:00  127118   11.176
# 967     Thomas    Male 2016-03-12 2021-02-03 15:10:00  105681   19.572
# 987     Gloria  Female 2014-12-08 2021-02-03 05:08:00  136709   10.331
# 995      Henry     NaN 2014-11-23 2021-02-03 06:09:00  132483   16.655
#
#      Senior Management       Team
# 7                 True  Marketing
# 15               False  Marketing
# ...
